# %%
#Open an inexistent file
open("./hola.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX Fullstack Course/Curso Python/CursoIntroPython/Módulo 10 - Manejo de errores/Modulo 10 - Ejercicios.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000000vscode-remote?line=0'>1</a> #Open an inexistent file
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000000vscode-remote?line=1'>2</a> open("./hola.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: './hola.txt'

# %%
#File open.py
def main():
    open("./hola.txt")

if __name__=='__main__':
    main()

# %% [markdown]
# ![](../images/module-10-terminal.PNG)

# %%
#Try to open the configuration file for the ship
try:
    open("config.txt")
except FileNotFoundError:
    print("Coldn't find the config.txt file!")
# Out:
# Coldn't find the config.txt file!

# %%
#File config.py
def main():
    try:
        configuration=open("config.txt")
    except FileNotFoundError:
        print("Coldn't find the config.txt file!")

if __name__=='__main__':
    main()

# %% [markdown]
# ![](../images/module-10-terminal-2.PNG)

# %%
# WRONG: Detect all the execptions
try:
    open("config.txt")
except Exception:
    print("Coldn't find the config.txt file!")
# Out:
# Coldn't find the config.txt file!

# %%
try:
    open("config.txt")
except FileNotFoundError:
    print("Coldn't find the config.txt file!")
except IsADirectoryError:
    print("Found config.txt but it is a directory, couldn't read it!")
# Out:
# Coldn't find the config.txt file!

# %%
try:
    open("config.txt")
except FileNotFoundError:
    print("Coldn't find the config.txt file!")
except IsADirectoryError:
    print("Found config.txt but it is a directory, couldn't read it!")
except (BlockingIOError, TimeoutError):
    print("Filesystem under heavy load, can't complete reading configuration file")
# Out:
# Coldn't find the config.txt file!

# %%
try:
    open("mars.jpg")
except FileNotFoundError as error:
    print("Got a problem trying to read the file:\n\t", error)
# Out:
# Got a problem trying to read the file:
# 	 [Errno 2] No such file or directory: 'mars.jpg'

# %%
try:
    open("config.txt")
except OSError as error:
    if error.errno == 2:
        print("Couldn't find the config.txt file:\n\t", error)
    elif error.errno == 13:
        print("Found config.txt but couldn't read it:\n\t", error)
# Out:
# Couldn't find the config.txt file:
# 	 [Errno 2] No such file or directory: 'config.txt'

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
water_left(5, 100, 2)
# Out:
# 'Total water left after 2 days is: -10 liters'

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
water_left(5, 100, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX Fullstack Course/Curso Python/CursoIntroPython/Módulo 10 - Manejo de errores/Modulo 10 - Ejercicios.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000015vscode-remote?line=0'>1</a> water_left(5, 100, 2)
#
# /mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX Fullstack Course/Curso Python/CursoIntroPython/Módulo 10 - Manejo de errores/Modulo 10 - Ejercicios.ipynb Cell 14' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000014vscode-remote?line=3'>4</a> total_water_left = water_left - total_usage
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000014vscode-remote?line=4'>5</a> if total_water_left < 0:
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000014vscode-remote?line=5'>6</a>     raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000014vscode-remote?line=6'>7</a> return f"Total water left after {days_left} days is: {total_water_left} liters"
#
# RuntimeError: There is not enough water for 5 astronauts after 2 days!

# %%
def water_left(astronauts, water_left, days_left):
    for argument in [astronauts, water_left, days_left]:
        try:
            # If argument is an int, the following operation will work
            argument / 10
        except TypeError:
            # TypError will be raised only if it isn't the right type 
            # Raise the same exception but with a better error message
            raise TypeError(f"All arguments must be of type int, but received: '{argument}'")
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
water_left("3", "200", None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX Fullstack Course/Curso Python/CursoIntroPython/Módulo 10 - Manejo de errores/Modulo 10 - Ejercicios.ipynb Cell 16' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=2'>3</a> try:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=3'>4</a>     # If argument is an int, the following operation will work
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=4'>5</a>     argument / 10
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=5'>6</a> except TypeError:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=6'>7</a>     # TypError will be raised only if it isn't the right type
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=7'>8</a>     # Raise the same exception but with a better error message
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX Fullstack Course/Curso Python/CursoIntroPython/Módulo 10 - Manejo de errores/Modulo 10 - Ejercicios.ipynb Cell 17' in <module>
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000017vscode-remote?line=0'>1</a> water_left("3", "200", None)
#
# /mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX Fullstack Course/Curso Python/CursoIntroPython/Módulo 10 - Manejo de errores/Modulo 10 - Ejercicios.ipynb Cell 16' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=4'>5</a>         argument / 10
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=5'>6</a>     except TypeError:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=6'>7</a>         # TypError will be raised only if it isn't the right type
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=7'>8</a>         # Raise the same exception but with a better error message
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=8'>9</a>         raise TypeError(f"All arguments must be of type int, but received: '{argument}'")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=9'>10</a> daily_usage = astronauts * 11
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/unopa/Documents/Adrian/Programacion/LauncherX%20Fullstack%20Course/Curso%20Python/CursoIntroPython/M%C3%B3dulo%2010%20-%20Manejo%20de%20errores/Modulo%2010%20-%20Ejercicios.ipynb#ch0000016vscode-remote?line=10'>11</a> total_usage = daily_usage * days_left
#
# TypeError: All arguments must be of type int, but received: '3'
